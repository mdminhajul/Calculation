# %% [markdown]
# <a href="https://colab.research.google.com/github/mdminhajul/Calculation/blob/main/Python_Math_Module_for_Scientific_Computing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpmath import mp

def print_pi_to_n_digits(n):
    # Set precision to n decimal places
    mp.dps = n + 1  # Adding 1 to account for the "3." before the decimals
    # Return pi to n decimal places as a string
    return str(mp.pi)

# %%
print_pi_to_n_digits(500)
# Out:
# '3....'
